# %%
#importamos las librerias necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn import metrics
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.metrics import silhouette_score
from scipy.cluster.hierarchy import cophenet
from scipy.spatial.distance import pdist
import warnings
warnings.filterwarnings('ignore')

# %%
#cargamos el data set
df = pd.read_csv("D:\Descargas\Mall_Customers.csv")
df.head(6)
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# 5           6  Female   22                  17                      76

# %%
df.shape
# Out:
# (200, 5)

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
dat=df.drop(['Gender'], axis=1)

# %%
dat.head()
# Out:
#    CustomerID  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1   19                  15                      39
# 1           2   21                  15                      81
# 2           3   20                  16                       6
# 3           4   23                  16                      77
# 4           5   31                  17                      40

# %%
dat.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
dat.isna().sum()
# Out:
# CustomerID                0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
#eliminamos valores faltantes
dat.dropna()
# Out:
#      CustomerID  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1   19                  15                      39
# 1             2   21                  15                      81
# 2             3   20                  16                       6
# 3             4   23                  16                      77
# 4             5   31                  17                      40
# ..          ...  ...                 ...                     ...
# 195         196   35                 120                      79
# 196         197   45                 126                      28
# 197         198   32                 126                      74
# 198         199   32                 137                      18
# 199         200   30                 137                      83
#
# [200 rows x 4 columns]

# %%
sns.pairplot(dat.dropna(), size=5,kind='scatter')

# %%
#creación de matriz de correlación
corr_matrix = dat.corr()
corr_matrix
# Out:
#                         CustomerID       Age  Annual Income (k$)  \
# CustomerID                1.000000 -0.026763            0.977548
# Age                      -0.026763  1.000000           -0.012398
# Annual Income (k$)        0.977548 -0.012398            1.000000
# Spending Score (1-100)    0.013835 -0.327227            0.009903
#
#                         Spending Score (1-100)
# CustomerID                            0.013835
# Age                                  -0.327227
# Annual Income (k$)                    0.009903
# Spending Score (1-100)                1.000000

# %%
# Diagramas de caja para cada variable por especie
sns.boxplot(data=data)
# Out:
# <Axes: >

# %%
#Se estandariza los datos para poder aplicar el metodo K-means
py = StandardScaler()
A = pd.DataFrame(py.fit_transform(data), columns = dat.columns)
A
# Out:
#      CustomerID       Age  Annual Income (k$)  Spending Score (1-100)
# 0     -1.723412 -1.424569           -1.738999               -0.434801
# 1     -1.706091 -1.281035           -1.738999                1.195704
# 2     -1.688771 -1.352802           -1.700830               -1.715913
# 3     -1.671450 -1.137502           -1.700830                1.040418
# 4     -1.654129 -0.563369           -1.662660               -0.395980
# ..          ...       ...                 ...                     ...
# 195    1.654129 -0.276302            2.268791                1.118061
# 196    1.671450  0.441365            2.497807               -0.861839
# 197    1.688771 -0.491602            2.497807                0.923953
# 198    1.706091 -0.491602            2.917671               -1.250054
# 199    1.723412 -0.635135            2.917671                1.273347
#
# [200 rows x 4 columns]

# %%
kda = range(1, 10)
kmeans = [KMeans(n_clusters=i) for i in Nc]
kmeans
puntuation = [kmeans[i].fit(A).score(A) for i in range(len(kmeans))]
puntuation
plt.plot(Nc,score, marker='o')
plt.xlabel('Número de Clusters')
plt.ylabel('Puntuación')
plt.title('Curva')
plt.show()

# %%
cluster1 = KMeans(n_clusters=3).fit(A)
Resultado = cluster1.cluster_centers_
Resultado
# Out:
# array([[-1.0239213 , -0.86423656, -0.98001477,  0.34984199],
#        [ 0.96109881, -0.3121851 ,  0.89912973,  0.06446185],
#        [-0.47436436,  1.15787451, -0.42523207, -0.38283068]])

# %%
salida = cluster1.labels_
# Obtenemos los centroids
B = cluster1.cluster_centers_
colors=['yellow','purple','fuchsia']
asignar=[]
for row in labels:
    asignar.append(colors[row])

# %%
f1 = X['Spending Score (1-100)'].values
f2 = X['CustomerID'].values
plt.scatter(f1, f2, c=asignar, s=70)
plt.scatter(C[:, 0], C[:, 1], marker='*', c=colores, s=1000)
plt.title('Datos')
plt.xlabel('Spending Score (1-100)')
plt.ylabel('CustomerID')
plt.show()

# %%
f1 = X['Annual Income (k$)'].values
f2 = X['CustomerID'].values
plt.scatter(f1, f2, c=asignar, s=70)
plt.scatter(C[:, 0], C[:, 1], marker='*', c=colores, s=1000)
plt.title('Datos')
plt.xlabel('Annual Income (k$)')
plt.ylabel('CustomerID')
plt.show()

# %%
f1 = X['Age'].values
f2 = X['CustomerID'].values
plt.scatter(f1, f2, c=asignar, s=70)
plt.scatter(C[:, 0], C[:, 1], marker='*', c=colores, s=1000)
plt.title('Datos')
plt.xlabel('Age')
plt.ylabel('CustomerID')
plt.show()

# %%
f1 = X['Annual Income (k$)'].values
f2 = X['Age'].values
plt.scatter(f1, f2, c=asignar, s=70)
plt.scatter(C[:, 0], C[:, 1], marker='*', c=colores, s=1000)
plt.title('Datos')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Age')
plt.show()

# %%
A_new = py.fit_transform(np.array([[5.4,3.3,1.2,0.25]]))  
new_label = cluster1.predict(A_new)
color=[]
for row in new_label:
    color.append(colores[row])    
print(new_label)
print(color)
# Out:
# [1]
# ['green']

# %%
#Calcular medidas para K-means
print("Medidas para K-means")
print("Silhouette:", metrics.silhouette_score(A, labels))
print("Calinski-Harabasz:", metrics.calinski_harabasz_score(A, labels))
print("Inertia (suma de cuadrados dentro de los clusters):", cluster1.inertia_)
print("Davies-Bouldin Index:", metrics.davies_bouldin_score(A, labels))
# Out:
# Medidas para K-means
# Silhouette: 0.33627250175154105
# Calinski-Harabasz: 111.48622496693119
# Inertia (suma de cuadrados dentro de los clusters): 375.2627107440475
# Davies-Bouldin Index: 1.0218705983348075
